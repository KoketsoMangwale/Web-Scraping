# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
url = "http://www.dha.gov.za/index.php/bids-awarded"

# %%
response = requests.get(url)

# %%
df_list = pd.read_html(response.text) # this parses all the tables in webpages to a list

# %%
# create a data frame
df = df_list[0]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
for i in range(1, len(df_list)):
  home_df = df.append(df_list, ignore_index=True)
  #car_trader = car_trader.append(car_trader_tmp,ignore_index=True)
# Out:
# <ipython-input-7-a7dbd0da8213>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   home_df = df.append(df_list, ignore_index=True)

# %%
home_df.head(10)
# Out:
#             0                                                  1  \
# 0  BID NUMBER                                        DESCRIPTION
# 1  DHA02-2023  Appointment of a service provider for the supp...
# 2  BID NUMBER                                        DESCRIPTION
# 3  DHA02-2023  Appointment of a service provider for the supp...
# 4  BID NUMBER                                        DESCRIPTION
# 5  DHA18-2022  Appointment a service provider/s to provide th...
# 6  DHA20-2022  Appointment of a suitable service provider(s) ...
# 7  DHA14-2022  Appointment of a service provider to avail and...
# 8  DHA11-2022  Appointment of a service provider to provide p...
# 9  DHA15-2022  Appointment of a service provider to provide w...
#
#                                         2  \
# 0                       SUCCESSFUL BIDDER
# 1          Muelelwa M Business Enterprise
# 2                       SUCCESSFUL BIDDER
# 3          Muelelwa M Business Enterprise
# ...

# %%
home_df.shape
# Out:
# (253, 5)

# %%
#save to excel or CSV
home_df.to_csv('home_affairs_copy.csv')
